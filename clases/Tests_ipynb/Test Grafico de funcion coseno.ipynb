# %% [markdown]
# ### Test Grafico para el coseno

# %% [markdown]
# #### La idea es hacer una herramienta sencilla y visual para checar que el computo del coseno esta bien hecho, una vez eso, el algoritmo de comprobacion general sera seguro en el caso de querer hacer alguna funcion coseno mas rapida

# %%
from intervalo import *
from matplotlib import pyplot as plt
import numpy as np
from test_intervalo import *
# %matplotlib inline

# %%
a = Intervalo(4.49204400923,10.6552293164)
graphic_cos(a)

# %%
graphic_cos(Intervalo(0,0.8))
